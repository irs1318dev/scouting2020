# %%
import bokeh.io
import bokeh_server_demo as bsd

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1040">Loading BokehJS ...</span>
#     </div>

# %%
pickle_file = 'test_evt2.pickle'
splot = bsd.Splotter(pickle_file)

# %%
cds = splot.task_mean_source()

# %%
cds.data
# Out:
# {'team': array(['7118', '6959', '6503', '6350', '5937', '5683', '4918', '4911',
#         '4579', '4461', '4131', '4089', '3876', '3786', '3684', '3393',
#         '3237', '3219', '3070', '3049', '2990', '2980', '2929', '2927',
#         '2926', '2907', '2906', '2097', '2046', '1318', '948', '492',
#         '360'], dtype=object),
#  'successes': array([1.5       , 2.83333333, 1.2       , 2.5       , 3.16666667,
#         2.66666667, 4.5       , 6.4       , 3.        , 3.2       ,
#         1.33333333, 2.33333333, 1.14285714, 4.16666667, 0.5       ,
#         1.8       , 2.5       , 2.28571429, 2.        , 5.        ,
#         4.83333333, 4.2       , 4.        , 0.6       , 2.83333333,
#         4.        , 3.33333333, 3.        , 2.16666667, 2.8       ,
#         3.5       , 2.71428571, 3.16666667]),
#  'attempts': array([1.5       , 3.5       , 1.4       , 5.        , 6.5       ,
#         4.        , 5.5       , 9.6       , 3.4       , 5.2       ,
# ...

# %%
bokeh.io.show(splot.plot_task_by_team('shootLower'))
# Out:
#   <div class="bk-root" id="8b740f58-7cf4-4229-a850-ca508cbbfcd1" data-root-id="1003"></div>

# %%
splot.get_tasks()
# Out:
# ['movedAuto',
#  'pickupPowerCellsG',
#  'crossOpponentSector',
#  'startingPosition',
#  'disabled',
#  'shootInner',
#  'shootUpper',
#  'climbPosition',
#  'pickupPowerCellsL',
#  'shootLower',
#  'collided',
#  'defense',
#  'positionControl',
#  'pickupPowerCellsT',
#  'tempDisabled',
#  'isLevel',
#  'rotationControl',
#  'pickupPowerCellsS',
#  'powerCellsLoaded',
#  'shootPowerCellsUpperBI',
#  'shootPowerCellsLowerBI',
#  'shootPowerCellsInnerBI',
#  'defendedAgainst',
#  'getFoul',
#  'card',
#  'fallOver',
#  'noShow',
#  'isActiveLevel']
